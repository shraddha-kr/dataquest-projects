# %% [markdown]
# PROJECT TITLE
# ------------------------
# Profitable App Profiles for the App Store and Google Play Markets
#
#
#
# PROJECT INTRODUCTION
# --------------------------------------
# A guided DQ project to apply the learnings of STEP 1: Introduction to Python.
#
#
# PROJECT GOAL
# -------------------------
# Our aim in this project is to find mobile app profiles that are profitable for the App Store and Google Play markets. We're working as data analysts for a company that builds Android and iOS mobile apps, and our job is to enable our team of developers to make data-driven decisions with respect to the kind of apps they build.
#
# At our company, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means that our revenue for any given app is mostly influenced by the number of users that use our app. Our goal for this project is to analyze data to help our developers understand what kinds of apps are likely to attract more users.

# %% [markdown]
# Opening and Exploring the Data
# ----------------------------------------------
# As of September 2018, there were approximately 2 million iOS apps available on the App Store, and 2.1 million Android apps on Google Play.
#
# Collecting data for over four million apps requires a significant amount of time and money, so we'll try to analyze a sample of data instead. To avoid spending resources with collecting new data ourselves, we should first try to see whether we can find any relevant existing data at no cost. Luckily, these are two data sets that seem suitable for our purpose.
#
# The documentation of the [Google data-set](https://www.kaggle.com/lava18/google-play-store-apps), contains data about approximately ten thousand Android apps from Google Play.
#
# The documentation of the [Apple data-set](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps), contains data about approximately seven thousand iOS apps from the App Store.

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row
                
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
from csv import reader

# google data-set
# google_data = open('../datasets/googleplaystore.csv', encoding="utf8")
google_data = open('googleplaystore.csv', encoding="utf8")
gread_file = reader(google_data)
google_datalist = list(gread_file)

# retrieve the header
google_header = google_datalist[0]

# retrieve the data-rows
google_datarows = google_datalist[1:]

# print the header
print(google_header)
print('\n')

# print the rows of data set using explore()
explore_data(google_datarows, 0, 5, True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# The columns that look important in concluding our analysis are 'App', 'Category', 'Rating',  'Installs', 'Content Rating', 'Type', 'Price', and 'Genres'.
#
#
# The documentation of the above [data set](https://www.kaggle.com/lava18/google-play-store-apps) containing data about approximately ten thousand Android apps from Google Play.

# %%
from csv import reader

# apple_data = open('../datasets/AppleStore.csv',  encoding="utf8")
apple_data = open('AppleStore.csv',  encoding="utf8")
aread_file = reader(apple_data)
apple_datalist = list(aread_file)

# retrieve the header
apple_header = apple_datalist[0]

# retrieve the data-rows
apple_datarows = apple_datalist[1:]

# print the header
print(apple_header)
print('\n')

# print the rows of data set using explore()
explore_data(apple_datarows, 0, 5, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# Number of rows: 7197
# Number of columns: 16

# %% [markdown]
# The columns that look important in concluding our analysis are 'track_name', 'price', 'rating_count_tot', 'user_rating','cont_rating', 'prime_genre'
#
# The documentation of the above [data set](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps) containing data about approximately seven thousand iOS apps from the App Store.

# %% [markdown]
# Deleting rows with wrong data for Google data set
# ------------------------------------------------------------------------

# %% [markdown]
# To confirm the discussion outlining the error for row 10472, have checked the data set with the length of the row, if a column value is missing the row length should be less than 13, which is the length for a good row.

# %%
for i, val in enumerate(google_datarows): 
    # List all the row's of data, which have missing columns
    if len(val) < 13:
        print('ROW DATA')        
        print(val, '\n')
        print('ROW INDEX')
        print(i)
# Out:
# ROW DATA
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
# ROW INDEX
# 10472

# %% [markdown]
# The row 10472, has a missing 'Category' column, which will be deleted as below.

# %%
print(len(google_datarows))
del google_datarows[10472]
print(len(google_datarows))
# Out:
# 10841
# 10840

# %% [markdown]
# Removing duplicate data rows
# --------------------------------------------
# Creating a data set which has data with unique app names having the maximun number of reviews

# %% [markdown]
# #### STEP 1: Identify total no of duplicate app rows

# %%
duplicate_apps = []
unique_apps = []

for app in google_datarows:
    name = app[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)
    
print('Number of duplicate apps:', len(duplicate_apps))
print('\n')
print('Examples of duplicate apps:', duplicate_apps[:15])
# Out:
# Number of duplicate apps: 1181
#
#
# Examples of duplicate apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software']

# %% [markdown]
# #### STEP 2: Create a unique dictionary with [AppName: MaxReviewCount]

# %%
uniqueapps_maxreview_dict = {}
for approw in google_datarows:
    name = approw[0]
    review_val = approw[3]
    if name in uniqueapps_maxreview_dict:
        curr_rev_val = uniqueapps_maxreview_dict[name]
        if review_val > curr_rev_val:
            uniqueapps_maxreview_dict.update({name: review_val})           
    else:
        uniqueapps_maxreview_dict.update({name: review_val})

print('[KEY]', '\t',  '[VALUE]')
for k in uniqueapps_maxreview_dict:
    print(k, '\t', uniqueapps_maxreview_dict[k])    
print('\n')
# Out:
# [KEY] 	 [VALUE]
# Photo Editor & Candy Camera & Grid & ScrapBook 	 159
# Coloring book moana 	 974
# U Launcher Lite – FREE Live Cool Themes, Hide Apps 	 87510
# Sketch - Draw & Paint 	 215644
# Pixel Draw - Number Art Coloring Book 	 967
# Paper flowers instructions 	 167
# Smoke Effect Photo Maker - Smoke Editor 	 178
# Infinite Painter 	 36815
# Garden Coloring Book 	 13791
# Kids Paint Free - Drawing Fun 	 121
# Text on Photo - Fonteee 	 13880
# Name Art Photo Editor - Focus n Filters 	 8788
# Tattoo Name On My Photo Editor 	 44829
# Mandala Coloring Book 	 4326
# 3D Color Pixel by Number - Sandbox Art Coloring 	 1518
# Learn To Draw Kawaii Characters 	 55
# Photo Designer - Write your name with shapes 	 3632
# 350 Diy Room Decor Ideas 	 27
# FlipaClip - Cartoon animation 	 194216
# ibis Paint X 	 224399
# Logo Maker - Small Business 	 450
# Boys Photo Editor - Six Pack & Men's Suit 	 654
# Superheroes Wallpapers | 4K Backgrounds 	 7699
# Mcqueen Coloring pages 	 65
# HD Mickey Minnie Wallpapers 	 118
# Harley Quinn wallpapers HD 	 192
# Colorfit - Drawing & Coloring 	 20260
# Animated Photo Editor 	 203
# Pencil Sketch Drawing 	 136
# Easy Realistic Drawing Tutorial 	 223
# Pink Silver Bow Keyboard Theme 	 1120
# Art Drawing Ideas 	 227
# Anime Manga Coloring Book 	 5035
# Easy Origami Ideas 	 1015
# I Creative Idea 	 353
# How to draw Ladybug and Cat Noir 	 564
# UNICORN - Color By Number & Pixel Art Coloring 	 8264
# Floor Plan Creator 	 36639
# PIP Camera - PIP Collage Maker 	 158
# How To Color Disney Princess - Coloring Pages 	 591
# Drawing Clothes Fashion Ideas 	 117
# Sad Poetry Photo Frames 2018 	 176
# Textgram - write on photos 	 295237
# Paint Splash! 	 2206
# Popsicle Sticks and Similar DIY Craft Ideas 	 26
# Canva: Poster, banner, card maker & graphic design 	 174531
# Install images with music to make video without Net - 2018 	 1070
# Little Teddy Bear Colouring Book Game 	 85
# How To Draw Food 	 845
# Monster Truck Stunt 3D 2019 	 367
# Real Tractor Farming 	 1598
# Ultimate F1 Racing Championship 	 284
# Used Cars and Trucks for Sale 	 17057
# American Muscle Car Race 	 129
# Offroad Oil Tanker Driver Transport Truck 2019 	 542
# Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru 	 10479
# Gas Prices (Germany only) 	 805
# Extreme Rally Championship 	 129
# Restart Navigator 	 1403
# REG - Check the regnumber, find information about Swedish vehicles 	 3971
# CityBus Lviv 	 534
# CDL Practice Test 2018 Edition 	 7774
# ezETC (ETC balance inquiry, meter trial, real-time traffic) 	 38846
# Free VIN Report for Used Cars 	 2431
# DMV Permit Practice Test 2018 Edition 	 6090
# Check Vehicle Tax 	 295
# Used Cars Mexico 	 190
# Ulysse Speedometer 	 40211
# REPUVE 	 356
# Used cars for sale - Trovit 	 52530
# Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines 	 116986
# SK Enca Direct Malls - Used Cars Search 	 1379
# Android Auto - Maps, Media, Messaging & Voice 	 271920
# PDD-UA 	 736
# Tickets SDA 2019 + Exam RF 	 7021
# Super Cars Wallpapers And Backgrounds 	 197
# Police Lights, Sirens & Follow Me 	 737
# Police Detector (Speed Camera Radar) 	 3574
# Best Car Wallpapers 	 994
# Tickets + PDA 2018 Exam 	 197136
# Pick Your Part Garage 	 142
# PakWheels: Buy & Sell Cars 	 15168
# Supervision service 	 2155
# Speed Camera Detector - Traffic & Speed Alert 	 138
# Used car search Goo net whole car Go to net 	 5414
# CarMax – Cars for Sale: Search Used Car Inventory 	 21777
# BEST CAR SOUNDS 	 348
# RST - Sale of cars on the PCT 	 250
# AutoScout24 Switzerland – Find your new car 	 13372
# Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo 	 7880
# SMS Park 	 3617
# SKencar 	 4806
# Fuelio: Gas log & costs 	 65786
# auto fines 	 31433
# Used car is the first car - used car purchase, used car quotation, dealer information to 	 5097
# All of the parking lot - National Park application (parking lot search / parking sharing / discount payment) 	 1754
# Inquiry Fines and Debits of Vehicles 	 2680
# Gas Station 	 1288
# Hush - Beauty for Everyone 	 18900
# ipsy: Makeup, Beauty, and Tips 	 49790
# Natural recipes for your beauty 	 1150
# BestCam Selfie-selfie, beauty camera, photo editor 	 1739
# Mirror - Zoom & Exposure - 	 32090
# Beauty Selfie Camera 	 2225
# Hairstyles step by step 	 4369
# Filters for Selfie 	 8572
# Tie - Always be happy 	 964
# Ulta Beauty 	 42050
# Prom MakeUp Tutorial 	 104
# Selfie Camera 	 17934
# Sweet Selfie Beauty Camera 	 601
# Colors of white in Urdu 	 36
# Selfie Camera Photo Editor & Filter & Sticker 	 187
# Wrinkles and rejuvenation 	 182
# Eyes Makeup Beauty Tips 	 30
# Photo Editor 2018 	 134
# Step By Step Eyes Makeup Tutorial 	 74
# Beauty Camera - Selfie Camera 	 113715
# Girls Hairstyles 	 3595
# Mirror Camera (Mirror + Selfie Camera) 	 9315
# Beauty Tips - Beauty Tips in Sinhala 	 75
# Haircut Tutorials/Haircut Videos 	 38
# Sephora: Skin Care, Beauty Makeup & Fragrance Shop 	 26834
# Manicure - nail design 	 119
# Sticker Camera - Selfie Filters, Beauty Camera 	 2277
# Filters for B Live 	 2280
# Skin Care and Natural Beauty 	 654
# Facial Wrinkle Reduction 	 184
# Makeup Videos 	 9
# Secrets of beauty, youth and health 	 77
# Recipes and tips for losing weight 	 35
# Discover Color 	 364
# Eyeliner step by step 2018 	 18
# Dresses Ideas & Fashions +3000 	 473
# Lady adviser (beauty, health) 	 30
# Step By Step Hairstyles For Women 	 66
# Rainbow Camera 	 3871
# Methods of teeth whitening 	 257
# Girls hairstyles 2018 	 62
# Wattpad 📖 Free Books 	 2915189
# E-Book Read - Read Book for free 	 1857
# Download free book with green book 	 4478
# Wikipedia 	 577550
# Amazon Kindle 	 814151
# Cool Reader 	 246315
# Dictionary - Merriam-Webster 	 454412
# NOOK: Read eBooks & Magazines 	 155466
# Free Panda Radio Music 	 418
# Book store 	 22486
# FBReader: Favorite Book Reader 	 203130
# English Grammar Complete Handbook 	 1435
# Free Books - Spirit Fanfiction and Stories 	 116507
# Google Play Books 	 1433233
# AlReader -any text book reader 	 90468
# Offline English Dictionary 	 860
# Oxford Dictionary of English : Free 	 364452
# Offline: English to Tagalog Dictionary 	 967
# Spanish English Translator 	 87919
# FamilySearch Tree 	 17506
# Cloud of Books 	 1862
# Recipes of Prophetic Medicine for free 	 2084
# ReadEra – free ebook reader 	 47303
# NOOK App for NOOK Devices 	 19090
# Anonymous caller detection 	 161
# Ebook Reader 	 85842
# Litnet - E-books 	 7831
# Read books online 	 91615
# English to Urdu Dictionary 	 4620
# eBoox: book reader fb2 epub zip 	 21336
# English Persian Dictionary 	 26875
# Flybook 	 1778
# All Maths Formulas 	 2709
# Ancestry 	 64513
# HTC Help 	 8342
# English translation from Bengali 	 527
# Pdf Book Download - Read Pdf Book 	 1322
# Free Book Reader 	 1680
# eBoox new: Reader for fb2 epub zip books 	 2739
# Only 30 days in English, the guideline is guaranteed 	 1065
# Moon+ Reader 	 233757
# SH-02J Owner's Manual (Android 8.0) 	 2
# English-Myanmar Dictionary 	 8788
# Golden Dictionary (EN-AR) 	 51269
# All Language Translator Free 	 30105
# Azpen eReader 	 156
# URBANO V 02 instruction manual 	 114
# English Dictionary - Offline 	 341234
# Visual Voicemail by MetroPCS 	 16129
# Indeed Job Search 	 674730
# Uber Driver 	 1254730
# ADP Mobile Solutions 	 85185
# Snag - Jobs Hiring Now 	 32584
# Docs To Go™ Free Office Suite 	 217730
# Google My Business 	 70991
# OfficeSuite : Free Office + PDF Editor 	 1002861
# USPS MOBILE® 	 16589
# Job Search by ZipRecruiter 	 148945
# Curriculum vitae App CV Builder Free Resume Maker 	 4571
# Google Primer 	 62272
# Alba Heaven - Alvarez Job Portal Services 	 8941
# SuperLivePro 	 46353
# Facebook Pages Manager 	 1279800
# OfficeSuite Pro + PDF (Trial) 	 88073
# My Space - Employment Center 	 67000
# Box 	 159872
# Polaris Office for LG 	 30847
# Call Blocker 	 188841
# Jobs in Alabama - Jobs in Alba 	 11622
# Square Point of Sale - POS 	 95912
# Plugin:AOT v5.0 	 4034
# Kariyer.net 	 45964
# SEEK Job Search 	 14955
# Become a Job - Find a job or advertise 	 6903
# ZOOM Cloud Meetings 	 31614
# Easy Installer - Apps On SD 	 23055
# Facebook Ads Manager 	 19051
# IndiaMART: Search Products, Buy, Sell & Trade 	 207372
# ViettelPost express delivery 	 1225
# MyASUS - Service Center 	 380837
# Job Korea - Career Jobs 	 10600
# 104 Looking for a job - looking for a job, looking for a job, looking for a part-time job, health checkup, resume, treatment
# Buff Thun - Daily Free Webtoon / Comics / Web Fiction / Mini Game 	 9952
# pixiv comic - everyone's manga app 	 18814
# Funny Jokes and Stories 2018 	 21
# Hojiboy Tojiboyev Life Hacks 	 15
# Perfect Viewer 	 51981
# Best Wallpapers Backgrounds(100,000+ 4K HD) 	 3596
# think Comics 	 1006
# Memes Button 	 5968
# Laftel - Watching and Announcing Snooping, Streaming 	 4895
# Messenger – Text and Video Chat for Free 	 56646578
# WhatsApp Messenger 	 69119316
# Messenger for SMS 	 125257
# Google Chrome: Fast & Secure 	 9643041
# Messenger Lite: Free Calls & Messages 	 1429038
# Gmail 	 4604483
# Hangouts 	 3419513
# Viber Messenger 	 11335481
# My Tele2 	 158679
# Firefox Browser fast & private 	 3075118
# Yahoo Mail – Stay Organized 	 4188345
# imo beta free calls and text 	 659395
# imo free video calls and chat 	 4785988
# Contacts 	 66602
# Call Free – Free Call 	 30209
# Web Browser & Explorer 	 36901
# Opera Mini - fast web browser 	 5150801
# Browser 4G 	 192948
# MegaFon Dashboard 	 99559
# ZenUI Dialer & Contacts 	 437674
# Cricket Visual Voicemail 	 13698
# Opera Browser: Fast and Secure 	 2473795
# TracFone My Account 	 20769
# Firefox Focus: The privacy browser 	 36981
# Google Voice 	 171052
# Chrome Dev 	 63576
# Xperia Link™ 	 45487
# TouchPal Keyboard - Fun Emoji & Android Keyboard 	 615381
# Who 	 2451093
# Skype Lite - Free Video Call & Chat 	 33053
# WeChat 	 5387631
# UC Browser Mini -Tiny Fast Private & Secure 	 3648765
# WhatsApp Business 	 137144
# My magenta 	 42370
# Android Messages 	 781810
# Telegram 	 3128611
# Google Duo - High Quality Video Calls 	 2083237
# Puffin Web Browser 	 541661
# Seznam.cz 	 46702
# Antillean Gold Telegram (original version) 	 2939
# AT&T Visual Voicemail 	 13761
# GMX Mail 	 258556
# Omlet Chat 	 40751
# UC Browser - Fast Download Private & Secure 	 17714850
# My Vodacom SA 	 25021
# Microsoft Edge 	 27187
# Hangouts Dialer - Call Phones 	 122512
# Talkatone: Free Texts, Calls & Phone Number 	 132015
# Calls & Text by Mo+ 	 83239
# free video calls and chat 	 594728
# Skype - free IM & video calls 	 10484169
# GO SMS Pro - Messenger, Free Themes, Emoji 	 2876500
# Messaging+ SMS, MMS Free 	 28238
# chomp SMS 	 335646
# Glide - Video Chat Messenger 	 350154
# Text SMS 	 349384
# Google Allo 	 347086
# Talkray - Free Calls & Texts 	 244863
# LINE: Free Calls & Messages 	 10790289
# GroupMe 	 330761
# mysms SMS Text Messaging Sync 	 37320
# BBM - Free Calls & Messages 	 12843436
# KakaoTalk: Free Calls & Text 	 2546549
# 2ndLine - Second Phone Number 	 15880
# CM Browser - Ad Blocker , Fast Download , Privacy 	 2265084
# Ninesky Browser 	 42925
# Dolphin Browser - Fast, Private & Adblock🐬 	 2511130
# Ghostery Privacy Browser 	 13100
# InBrowser - Incognito Browsing 	 27156
# Web Browser for Android 	 55110
# DU Browser—Browse fast & fun 	 1133539
# Lightning Web Browser 	 12578
# Web Browser 	 10965
# Puffin Browser Pro 	 18247
# Contacts+ 	 190613
# ExDialer - Dialer & Contacts 	 125232
# PHONE for Google Voice & GTalk 	 72065
# Safest Call Blocker 	 27540
# Full Screen Caller ID 	 104990
# Hiya - Caller ID & Block 	 177703
# Mr. Number-Block calls & spam 	 177263
# Should I Answer? 	 237468
# RocketDial Dialer & Contacts 	 32254
# CallApp: Caller ID, Blocker & Phone Call Recorder 	 483782
# Whoscall - Caller ID & Block 	 552635
# CIA - Caller ID & Call Blocker 	 60308
# Calls Blacklist - Call Blocker 	 457283
# Call Control - Call Blocker 	 93825
# True Contact - Real Caller ID 	 32283
# Video Caller Id 	 15287
# Sync.ME – Caller ID & Block 	 205739
# Burner - Free Phone Number 	 14873
# Truecaller: Caller ID, SMS spam blocking & Dialer 	 7820775
# Caller ID + 	 9498
# K-9 Mail 	 88427
# myMail – Email for Hotmail, Gmail and Outlook Mail 	 305218
# Email TypeApp - Mail App 	 183374
# All Email Providers 	 20901
# Newton Mail - Email App for Gmail, Outlook, IMAP 	 122595
# GO Notifier 	 124346
# Mail.Ru - Email App 	 837842
# Mail1Click - Secure Mail 	 255
# Daum Mail - Next Mail 	 41420
# mail.com mail 	 44706
# SolMail - All-in-One email app 	 23707
# Vonage Mobile® Call Video Text 	 29208
# JusTalk - Free Video Calls and Fun Video Chat 	 191032
# Moco+ - Chat, Meet People 	 1546
# Calculator 	 57
# Truth or Dare Pro 	 0
# Private Dating, Hide App- Blue for PrivacyHider 	 0
# Ad Blocker for SayHi 	 4
# AMBW Dating App: Asian Men Black Women Interracial 	 2
# Zoosk Dating App: Meet Singles 	 516917
# OkCupid Dating 	 285838
# Match™ Dating - Meet Singles 	 76646
# Hily: Dating, Chat, Match, Meet & Hook up 	 2560
# Hinge: Dating & Relationships 	 7779
# Casual Dating & Adult Singles - Joyride 	 61637
# BBW Dating & Plus Size Chat 	 12633
# Moco - Chat, Meet People 	 313769
# CMB Free Dating App 	 48845
# Hot or Not - Find someone right now 	 305737
# eharmony - Online Dating App 	 31320
# Free Dating App & Flirt Chat - Match with Singles 	 172460
# Chispa, the Dating App for Latino, Latina Singles 	 4195
# Clover Dating App 	 11633
# Black People Meet Singles Date 	 10212
# Mingle2 - Free Online Dating & Singles Chat Rooms 	 37053
# Free Dating App & Flirt Chat - Cheers 	 667
# stranger chat - anonymous chat 	 13204
# Blendr - Chat, Flirt & Meet 	 28671
# Free Dating Hook Up Messenger 	 1157
# Find Real Love — YouLove Premium Dating 	 212626
# Once - Quality Matches Every day 	 222888
# BLK - Swipe. Match. Chat. 	 2067
# Cougar Dating Life : Date Older Women Sugar Mummy 	 1645
# Howlr 	 105
# Stranger Chat & Date 	 3414
# Free Dating & Flirt Chat - Choice of Love 	 42197
# RandoChat - Chat roulette 	 11806
# BeWild Free Dating & Chat App 	 1999
# FastMeet: Chat, Dating, Love 	 22545
# Free Dating App - YoCutie - Flirt, Chat & Meet 	 97699
# OurTime Dating for Singles 50+ 	 2519
# FarmersOnly Dating 	 1146
# Dating for 50 plus Mature Singles – FINALLY 	 13049
# PINKFONG Baby Shark 	 10852
# English words application mikan 	 9888
# Learn English for beginners 	 1929
# Listen and learn English in seven days 	 1516
# Lumosity: #1 Brain Games & Cognitive Training App 	 215301
# Learn English from Persian: Persian to English 	 423
# English with Lingualeo 	 254519
# Learn languages, grammar & vocabulary with Memrise 	 1107948
# Quizlet: Learn Languages & Vocab with Flashcards 	 211856
# Udemy - Online Courses 	 99020
# Coursera: Online courses 	 90481
# edX - Online Courses by Harvard, MIT & more 	 32381
# Elevate - Brain Training Games 	 248912
# NeuroNation - Focus and Brain Training 	 248555
# Peak – Brain Games & Training 	 272321
# Memorado - Brain Games 	 56897
# Lynda - Online Training Videos 	 8599
# Brilliant 	 41185
# CppDroid - C/C++ IDE 	 29980
# Quiz&Learn Python 	 304
# C++ Tutorials 	 358
# C++ Programming 	 11904
# C Programming 	 22251
# Udacity - Lifelong Learning 	 22384
# Learn C++ 	 73404
# Learn programming 	 12733
# Learn JavaScript 	 25183
# Learn Java 	 52743
# Learn HTML 	 61749
# Programming Hub, Learn to code 	 55704
# Learn SQL 	 19277
# Ready4 SAT (Prep4 SAT) 	 13612
# Socratic - Math Answers & Homework Help 	 37862
# Ready4 GMAT (Prep4 GMAT) 	 18372
# Pocket GMAT Math 	 656
# GMAT Question Bank 	 240
# GRE Tutor 	 275
# GRE Flashcards 	 13791
# play2prep: ACT, SAT prep 	 3692
# SAT Test 	 2363
# GMAT Math Flashcards 	 1769
# Pocket SAT Math 	 430
# TOEFL Prep & Practice from Magoosh 	 756
# GRE Prep & Practice by Magoosh 	 3963
# GRE® Flashcards by Kaplan 	 316
# SAT Vocabulary 	 642
# Magoosh GMAT Prep & Practice 	 1058
# SAT Flashcards: Prep & Vocabulary 	 2277
# Rosetta Stone: Learn to Speak & Read New Languages 	 172508
# Google Classroom 	 69498
# LinkedIn Learning: Online Courses to Learn Skills 	 7973
# Learn English with Phrases 	 5695
# Free english course 	 142632
# Learn 50 languages 	 55256
# Babbel – Learn Spanish 	 54798
# Mango Languages: Lovable Language Courses 	 4815
# Learn English with Aco 	 75112
# Learn to Speak English 	 33646
# busuu: Learn Languages - Spanish, English & More 	 207294
# My Class Schedule: Timetable 	 9348
# Study Checker 	 3816
# My Study Life - School Planner 	 47847
# HomeWork 	 16195
# Next Gen Science Standards 	 206
# myHomework Student Planner 	 28392
# Teacher's Gradebook - Additio 	 3241
# Common Core 	 835
# Homework Planner 	 2525
# TeachersPayTeachers 	 828
# Edmodo 	 200214
# Socrative Teacher 	 1239
# Training schedule - AllUniver 	 702
# Remind: School Communication 	 108613
# ClassDojo 	 148550
# Lerni. Learn languages. 	 3847
# HelloTalk — Chat, Speak & Learn Foreign Languages 	 84311
# Innovative: Learn 34 Languages 	 14206
# Chegg Study - Homework Help 	 14700
# Canvas Student 	 42828
# Timetable 	 40209
# EasyBib: Citation Generator 	 1405
# SoloLearn: Learn to Code for Free 	 256079
# Kids Learn Languages by Mondly 	 2078
# Blinkist - Nonfiction Books 	 16103
# Sago Mini Hat Maker 	 11
# Fuzzy Numbers: Pre-K Number Foundation 	 21
# USE Credit Union Mobile 	 964
# Discover Mobile 	 87951
# Amex Mobile 	 24729
# Citi Mobile® 	 78306
# Navy Federal Credit Union 	 43313
# Chase Mobile 	 1374549
# HDFC Bank MobileBanking 	 208463
# Barclays US for Android 	 6998
# McDonald's 	 145646
# Easy and Fast Recipes 	 95
# Cookpad - FREE recipe search makes fun cooking · musical making! 	 64784
# DELISH KITCHEN - FREE recipe movies make food fun and easy! 	 32997
# Sumine side dish - dish recipe side dish 	 82
# Easy Recipes 	 2707
# Delicious Recipes 	 129737
# Tastely 	 611136
# Pastry & Cooking (Without Net) 	 6118
# Frigo Magic: Easy recipe idea and anti-waste 	 2473
# McDonald's - McDonald's Japan 	 109784
# Debonairs Pizza 	 3320
# Popeyes® App 	 61
# Dunkin' Donuts 	 68270
# Pyaterochka 	 8412
# Refreshing app Free application that can use deal coupons 	 10741
# Simple Recipes 	 3803
# Grubhub: Food Delivery 	 155944
# Panera Bread 	 10225
# Chick-fil-A 	 28009
# hellofood - Food Delivery 	 43614
# Starbucks 	 455496
# Easy and quick desserts 	 1398
# Domino's Pizza USA 	 1032935
# Chef - Recipes & Cooking 	 32405
# Delivery Club-food delivery: pizza, sushi, burger, salad 	 151080
# HungerStation 	 22513
# Delivery yogi. 	 90042
# Delivery trough - delivery trough delivery trough 	 58316
# Dr. Oetker recipe ideas 	 8509
# SONIC Drive-In 	 19373
# SUBWAY® 	 21381
# GialloZafferano: Recipes 	 30224
# Dairy Queen 	 742
# 9th stage 	 454
# OpenRice 	 14952
# SarashpazPapion (Cooking with Chef Bowls) 	 1250
# Little Caesars 	 1726
# Recipes Pastries and homemade pies More than 500 recipes for pastries 	 14065
# Om Waleed Sweets 	 556
# Eat Fast Prepare "Without Internet" 	 4925
# Wendy’s – Food and Offers 	 6512
# My Recipes Cookbook : RecetteTek 	 11707
# Healthy Recipes Free 	 1077
# Cookbook Recipes 	 46539
# ChefTap Recipes & Grocery List 	 9066
# Recipe Keeper 	 1962
# My CookBook (Recipe Manager) 	 22071
# 50 Healthy Slow Cooker Recipes 	 196
# Easy Healthy Recipes 	 278
# Allrecipes Dinner Spinner 	 61881
# My CookBook Pro (Ad Free) 	 2129
# Paprika Recipe Manager 	 1268
# Yummly Recipes & Shopping List 	 91359
# Kitchen Stories - Recipes & Cooking 	 22015
# Cookpad 	 131569
# BigOven Recipes, Meal Planner, Grocery List & More 	 31986
# Postmates Food Delivery: Order Eats & Alcohol 	 22875
# Instacart: Grocery Delivery 	 17071
# OpenTable: Restaurants Near Me 	 90242
# Foursquare City Guide 	 483960
# Zomato - Restaurant Finder and Food Delivery App 	 511420
# Munchery: Chef Crafted Fresh Food Delivered 	 464
# delivery.com: Order Food, Alcohol & Laundry 	 1920
# Eat24 Food Delivery & Takeout 	 40116
# BeyondMenu Food Delivery 	 51543
# EatStreet Food Delivery App 	 7690
# Pizza Hut 	 321134
# Caviar - Food Delivery 	 3755
# DoorDash - Food Delivery 	 104504
# Uber Eats: Local Food Delivery 	 333208
# Seamless Food Delivery/Takeout 	 35218
# Talabat: Food Delivery 	 116403
# TheFork - Restaurants booking and special offers 	 37517
# foodpanda - Local Food Delivery 	 292969
# Home Workout - No Equipment 	 432160
# Step Counter - Calorie Counter 	 1577
# Lose Belly Fat in 30 Days - Flat Stomach 	 38098
# Pedometer - Step Counter Free & Calorie Burner 	 31139
# Six Pack in 30 Days - Abs Workout 	 272337
# Lose Weight in 30 Days 	 220125
# Pedometer 	 400592
# LG Health 	 20098
# Step Counter - Pedometer Free & Calorie Counter 	 117925
# Pedometer, Step Counter & Weight Loss Tracker App 	 548021
# Sportractive GPS Running Cycling Distance Tracker 	 48276
# 30 Day Fitness Challenge - Workout at Home 	 471036
# Home Workout for Men - Bodybuilding 	 12705
# Fat Burning Workout - Home Weight lose 	 706
# Buttocks and Abdomen 	 465
# Walking for Weight Loss - Walk Tracker 	 644
# Running & Jogging 	 6238
# Walk with Map My Walk 	 144050
# Sleep Sounds 	 51227
# Fitbit 	 357417
# Lose Belly Fat-Home Abs Fitness Workout 	 199
# Runtastic Running App & Mile Tracker 	 827653
# Cycling - Bike Tracker 	 9116
# Abs Training-Burn belly fat 	 2071
# Calorie Counter - EasyFit free 	 50294
# Nike+ Run Club 	 708753
# Aunjai i lert u 	 1140
# Garmin Connect™ 	 232153
# BetterMe: Weight Loss Workouts 	 14709
# Bike Computer - GPS Cycling Tracker 	 12029
# Calorie Counter - MyFitnessPal 	 1873523
# Six Packs for Man–Body Building with No Equipment 	 2880
# Weight Watchers Mobile 	 270294
# Endomondo - Running & Walking 	 559262
# Running Distance Tracker + 	 77777
# The TK-App - everything under control 	 8642
# Runkeeper - GPS Track Run Walk 	 501144
# Walking: Pedometer diet 	 1861
# Recipes for hair and face tried 	 1203
# Abs Workout - 30 Days Fitness App for Six Pack Abs 	 299
# 8fit Workouts & Meal Planner 	 115721
# Keep Trainer - Workout Trainer & Fitness Coach 	 14810
# Run with Map My Run 	 183669
# Weight Loss Running by Verv 	 27396
# Couch to 10K Running Trainer 	 10445
# PumpUp — Fitness Community 	 49479
# Home workouts - fat burning, abs, legs, arms,chest 	 4848
# Running Weight Loss Walking Jogging Hiking FITAPP 	 20812
# Strava Training: Track Running, Cycling & Swimming 	 328469
# Workout Trainer: fitness coach 	 100406
# Fabulous: Motivate Me! Meditate, Relax, Sleep 	 205299
# StrongLifts 5x5 Workout Gym Log & Personal Trainer 	 66791
# 7 Minute Workout 	 399009
# Workout Tracker & Gym Trainer - Fitness Log Book 	 5420
# Freeletics: Personal Trainer & Fitness Workouts 	 130104
# Nike Training Club - Workouts & Fitness Plans 	 251618
# Fitbit Coach 	 28951
# JEFIT Workout Tracker, Weight Lifting, Gym Log App 	 60096
# Map My Ride GPS Cycling Riding 	 106547
# Daily Workouts - Exercise Fitness Routine Trainer 	 134195
# Google Fit - Fitness Tracking 	 249855
# Sworkit: Workouts & Fitness Plans 	 109756
# Map My Fitness Workout Trainer 	 38343
# Sports Tracker Running Cycling 	 190247
# Seven - 7 Minute Workout Training Challenge 	 75571
# Daily Yoga - Yoga Fitness Plans 	 70769
# Pocket Yoga 	 2107
# Been Together (Ad) - D-day 	 95736
# WedMeGood - Wedding Planner 	 1658
# DIY Garden Ideas 	 3309
# Brit + Co 	 987
# Creative Ideas - DIY & Craft 	 5208
# Homestyler Interior Design & Decorating Ideas 	 78298
# Wheretoget: Shop in style 	 6808
# My Dressing - Fashion closet 	 12452
# Chictopia 	 360
# Scarf Fashion Designer 	 16637
# Zara 	 95905
# Real Estate by Movoto 	 3114
# Etta Homes 	 220
# Houlihan Lawrence 	 33
# Home Scouting® MLS Mobile 	 1533
# Housing-Real Estate & Property 	 28301
# ZipRealty Real Estate & Homes 	 3937
# Sotheby's International Realty 	 894
# Zoopla Property Search UK - Home to buy & rent 	 21195
# Neighborhoods & Apartments 	 2042
# Keller Williams Real Estate 	 13213
# Relax Rain ~ Rain Sounds 	 118034
# Relax Ocean ~ Nature Sounds 	 9464
# Bed Time Fan - White Noise Sleep Sounds 	 10097
# Nature Sounds 	 28588
# SleepyTime: Bedtime Calculator 	 19621
# White Noise Baby 	 10544
# White Noise ~ Sleeping Sounds 	 4427
# Journey - Diary, Journal 	 50338
# 7 Day Food Journal Challenge 	 3346
# ROBLOX 	 4450890
# Subway Surfers 	 27725352
# Candy Crush Saga 	 22430188
# Solitaire 	 685
# Bubble Shooter 	 59843
# Hello Kitty Nail Salon 	 369378
# slither.io 	 5235294
# Clash Royale 	 23136735
# Temple Run 2 	 8119154
# Pou 	 10486018
# Helix Jump 	 1500999
# Block Puzzle 	 59907
# Angry Birds Rio 	 2610680
# Plants vs. Zombies FREE 	 4067651
# Sonic Dash 	 3778921
# Candy Crush Soda Saga 	 6199095
# Zombie Hunter King 	 10538
# Clash of Clans 	 44893888
# Kick the Buddy 	 1004709
# Block Puzzle Classic Legend ! 	 17044
# PAC-MAN 	 685981
# Super Jim Jump - pixel 3d 	 10460
# 8 Ball Pool 	 14201891
# Magic Tiles 3 	 592504
# Bubble Witch 3 Saga 	 1732263
# ...
# FC Porto 	 15883
# Fulham FC 	 401
# Barcelona FC Noticias Live 	 2
# Chelsea FC Official Keyboard 	 91397
# Burnley FC 	 195
# Atlanta United FC 	 215
# Barcelona Wallpaper HD 	 93
# Sydney FC Official App 	 57
# Birmingham City FC 	 191
# FC Browser - Focus Privacy Browser 	 26
# My AEK - Official ΑΕΚ FC app 	 3346
# FC Parking 	 0
# Noticias FC Barcelona 	 4
# Toronto FC 	 144
# Middlesbrough FC Official 	 152
# Galaxian(FC) 	 2
# FC Red Bull Salzburg App 	 1526
# FC Zenit official Android app 	 5675
# Fan App for Portsmouth FC 	 53
# Latest Barcelona News 24h 	 104
# Mobile FC 	 5015
# FirstCry Baby & Kids Shopping, Fashion & Parenting 	 41074
# Fan App for Reading FC 	 9
# Deportivo Toluca FC 	 2317
# Underdog FC 	 216
# Las Vegas Lights FC 	 10
# APOEL FC 	 688
# FD Shift Calendar Widget 	 981
# Bank FD Interest Calculator 	 166
# FD VR Video Player - (Stored) 	 751
# FD Mobile 	 53
# Formula DRIFT 	 169
# FD VR - Virtual 3D Web Browser 	 729
# FD Community FCU Mobile 	 175
# Female Daily 	 4354
# FD VR - Virtual App Launcher 	 1463
# FD VR Player - for 360 Youtube 	 100
# FD VR Store -VR Games and Apps 	 105
# Policy And FD Manager 	 20
# FD VR - Virtual Reality Camera 	 1007
# Sports Lite 	 16
# FD VR Theater - for Youtube VR 	 4585
# Story Time FD 	 2
# FD Calculator | Term Deposit | Fixed Deposit 	 12
# FD CANNECT 	 1
# Financial Calculator India 	 13819
# FD Calculator (EMI, SIP, RD & Loan Eligilibility) 	 104
# FD VR Cardboard Featured 360 Videos 	 76
# EMI, FD, RD - Bank Calculator 	 42
# FD VR Player - for Youtube 3D 	 2378
# RD/FD Calculator 	 92
# FD VR Music Videos - MTV Pop and Rap in 360 	 15
# FD VR - Virtual Photo Gallery 	 179
# Fix Deposit Calculator (FD) 	 7
# FD Interest Calculator 	 17
# Deposit Calculator FD & RD 	 18
# FD Fotografia 	 2
# Banking Calculator 	 3704
# FD e-paper 	 183
# FD Fitness 	 3
# EMI/FD/RD/PV/IRR/BEP/EOQ Calc 	 58
# EMI Calculator | FD Calculator | RD calculator 	 106
# LineStar for FanDuel 	 1539
# HD Video Download for Facebook 	 20755
# Fire Emblem Heroes 	 407694
# Santa Fe FCU Mobile Banking 	 12
# FE Connect 	 24
# FE Civil Engineering Exam Prep 	 9
# FE CREDIT - TET VUI 	 125
# FE Mechanical Engineering Prep 	 2
# FE Mobile 	 2
# Comunidad De Fe Minitries 	 19
# FE Other Disciplines Engineering Exam Prep 	 0
# FE EN ACCIÓN RADIO 	 1
# FE Electric & Comp Engineering 	 2
# Caprock Santa Fe Credit Union 	 0
# FE Chemical Engineering Exam Prep 	 2
# Santa Fe Map and Walks 	 2
# FE IP 	 3
# Safe Santa Fe 	 2
# Santa Fe New Mexican e-Edition 	 25
# L!FE Premium Training 	 2
# Theme for Galaxy Note FE Launcher | Live Wallpaper 	 2
# Theme for Galaxy Note FE 	 3
# Note FE Theme And Launcher For Samsung Galaxy 	 7
# FE CPS 	 62
# La Fe de Jesus 	 8
# Santa Fe Indian Market 	 4
# FE Connect Fhoton 	 0
# Repair Hyundai Santa Fe 	 22
# La Fe de Jesús 	 10
# Santa Fe Espresso & News 	 0
# Santa Fe Sentry 	 0
# Santa Fe Thrive 	 2
# FE Connect Drive-Tech 	 0
# FE Mix - Jokes - Status - Wallpaper 	 3
# Frases Cristianas de Esperanza y Fe 	 2
# Theme for Samsung Galaxy Note FE 	 52
# Santa Fe VIP Tours 	 1
# Santa Fe App 	 196
# Curso Básico y Avanzado la Fe de Jesús Audio-Texto 	 0
# Ríos de Fe 	 141
# Theme For Galaxy Note FE 	 0
# Le Fe de Jesus 	 3
# FG Mobile 	 130
# FG Wallet 	 9
# Burn Your Fat With Me! FG 	 38487
# FG On-The-Go 	 55
# FG Autumn Photo Puzzle 	 0
# Radio FG Paris Underground 	 3
# FG Radio - Radios de France 	 0
# FG SPINNER 	 2
# FG Finder 	 154
# FG. Chic - House Lounge Musique - Radios de France 	 1
# BROTHER IN WARS: GUNNER CITY WARLORDS 	 8649
# Kernel Manager for Franco Kernel ✨ 	 12700
# Qarabağ FK 	 9
# FK Sloboda Tuzla 	 0
# FK Jelgava 	 0
# FK Vojvodina 	 5
# FK Liepaja 	 4
# FK Teplice 	 2
# FK Sarajevo 	 6
# FK Vardar 	 2
# Ray Financial Calculator Pro 	 67
# FK Bregalnica Štip 	 0
# FK Mladost Lucani 	 0
# FK Radnicki Nis 	 1
# FK Dukla Prague 	 0
# FK Rad 	 1
# FK Jablonec 	 2
# FK Senica 	 0
# FK Vozdovac 	 1
# Toy Truck Rally 3D 	 301895
# FK Mladá Boleslav 	 0
# FK Macva Sabac 	 3
# FK Crvena zvezda 	 1211
# FK Events 	 0
# PRO MX MOTOCROSS 2 	 25275
# FK Jonava 	 1
# FK Željezničar Izzy 	 119
# FK Čukarički 	 0
# Austria Wien FK - Fussball - Inoffizielle App 	 2
# FK Železiarne Podbrezová 	 0
# FK Viktoria Žižkov 	 0
# FK Zemun 	 3
# FK Atlantas 	 2
# FK Spartak Subotica 	 0
# FK Dedinje BGD 	 36
# FK Fotbal Třinec 	 0
# FK Crvena Zvezda Izzy 	 1456
# FK Utenis Utena 	 0
# Crazy Freekick 	 47688
# FL State Parks Guide 	 871
# FL SW Fishing Regulations 	 60
# Permit Test FL Florida DHSMV 	 246
# FL Lottery Results 	 1481
# Florida DMV Permit Test -Fl 	 87
# Lottery Results: Florida 	 582
# Scratch-Off Guide for FL Lotto 	 25
# Charlotte County, FL 	 10
# Results for FL Lottery 	 146
# Check Lottery Tickets - Florida 	 27
# Fish|Hunt FL 	 853
# Florida 511 	 148
# Florida Storms 	 116
# FL Racing Manager 2018 Lite 	 1338
# Florida Tides & Weather 	 30
# FL Tax-Verify 	 17
# FL House 	 29
# FL Racing Manager 2015 Pro 	 656
# Lottery Driver- Florida Result 	 70
# Florida Travel Guide 	 11
# The Florida Trail Guide 	 100
# Florida - Pocket Brainbook 	 7
# Lottery Ticket Checker - Florida Results & Lotto 	 3
# Florida Statutes (FL Code) 	 5
# Discovery Church Florida 	 40
# FL Racing Manager 2018 Pro 	 340
# Florida Driver License Test 	 65
# Free Florida DMV Test 2018 	 665
# Canvas FL 	 36
# Florida Lottery Results 	 763
# Florida Cooling Supply HVAC 	 6
# Restaurant Inspections - FL 	 143
# Florida Keys 	 92
# South Florida AA Meetings 	 10
# Florida Travel Guide - TOURIAS 	 80
# Florida State Gameday 	 1566
# FL Bankers 	 0
# Fort Myers FL 	 0
# News-Journal-Daytona Beach, FL 	 76
# Florida map 	 11
# Trinity Church Deltona, FL 	 33
# FL Drone 2 	 41
# Beacon Baptist Jupiter, FL 	 14
# Clearwater, FL - weather and more 	 0
# University of Florida 	 168
# Ocala Star Banner, FL 	 75
# Alachua County Sheriff FL 	 5
# Lotto Results - Mega Millions Powerball Lottery US 	 14221
# Jax Sheriff (FL) 	 53
# Results for FL Lottery (Florida) 	 1
# Hidden Object Florida Vacation Adventure Fun Game 	 126
# WFLA News Channel 8 - Tampa FL 	 133
# Florida Beach Wallpapers HD 	 3
# MY GULFPORT FL 	 0
# My MLS App 	 1213
# Employ Florida Mobile 	 97
# St. Petersburg, FL - weather and more 	 0
# LifePoint Church - FL 	 1
# WSVN • South Florida's Source for Weather 	 7
# PriorityONE Credit Union of Fl 	 178
# Florida Wildflowers 	 5
# Florida Blue 	 499
# ORLANDO FLORIDA MAP 	 3
# Florida Tech Mobile 	 87
# Florida Offline Road Map 	 144
# Florida Map offline 	 8
# The Ledger - Lakeland, Florida 	 89
# FRONTLINE COMMANDO 	 1351833
# Gainesville Florida Police Department 	 4
# Gainesville Bus Tracker 	 63
# Florida Today 	 202
# Florida HSMV Driver License 	 14
# WSVN - 7 News Miami 	 3320
# WICShopper 	 3023
# First Federal Bank of Florida 	 133
# South Florida MLS 	 133
# Football Manager Mobile 2018 	 11460
# FN Cam 	 181
# How it Works: FN SCAR assault rifle 	 44
# FN pistol Model 1906 explained 	 1
# FN pistol model 1903 explained 	 1
# FutureNet your social app 	 2093
# Jigsaw Puzzles FN FAL Light Automatic Rifle 	 0
# Wallpapers FN Herstal FNP 9 	 0
# Ninja FN Button 	 12
# Wallpapers FN SCAR H 	 4
# Wallpapers FN F2000 	 0
# Wallpapers FN Five seven 	 0
# FN 	 14
# Wallpapers FN FAL Light Automatic Rifle 	 0
# The FN "Baby" pistol explained 	 1
# FN FAL rifle explained 	 1
# F N Bail Bonds 	 4
# The FN HP pistol explained 	 1
# SB · FN 1870 Mobile Banking 	 139
# PIP-Camera FN Photo Effect 	 8
# Bullet - FN Theme 	 143
# FN model 1900 pistol explained 	 0
# Pistolet FN GP35 expliqué 	 2
# FN Web Radio 	 0
# Gun Builder ELITE 	 88941
# FNH Payment Info 	 0
# Magnum 3.0 Gun Custom SImulator 	 16815
# Pistolet FN 1906 expliqué 	 0
# Circle Colors Pack-FN Theme 	 6
# Calculator Fn 	 9
# Pint - FN Theme 	 6
# HAL-9000 - FN Theme 	 159
# Solitaire+ 	 11235
# Fresh News 	 2207
# Future Cloud 	 1075
# Fruit Ninja Classic 	 85468
# Hunting Safari 3D 	 36183
# Gun Club Armory 	 55014
# Ethical Hacking 	 128
# Armed Cam Gun Pack 	 1012
# Zombie Defense 	 275048
# Fo File Manager 	 1916
# Alarm.fo – choose your info 	 19
# FO Bixby 	 5
# Pin-fo 	 19
# MARKET FO 	 0
# FO OP St-Nazaire 	 1
# FO SODEXO 	 0
# FO RCBT 	 5
# FO Interim 	 1
# Mu.F.O. 	 2
# FO PSA Sept-Fons 	 2
# FO BOULANGER 	 10
# FO AIRBUS TLSE 	 4
# F-O-Meter 	 0
# Theme fo Oppo A30 Wallpaper & Icon 	 7
# Fo Fo Fish 	 5
# FO STELIA Méaulte 	 2
# RRIMS FO 	 2
# Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 Note 	 7
# Photo Editor Collage Maker Pro 	 1519671
# Custos F.O. 	 0
# FO AIRBUS Nantes 	 0
# Stylish Fonts 	 153176
# 4x4 Jeep Racer 	 7279
# Lalafo Pulsuz Elanlar 	 61392
# My Earthquake Alerts - US & Worldwide Earthquakes 	 3471
# Castle Clash: RPG War and Strategy FR 	 376223
# Fr Lupupa Sermons 	 19
# FR Plus 1.6 	 4
# Fr Agnel Pune 	 80
# DICT.fr Mobile 	 20
# FR: My Secret Pets!  	 785
# Golden Dictionary (FR-AR) 	 5775
# FieldBi FR Offline 	 2
# HTC Sense Input - FR 	 885
# Gold Quote - Gold.fr 	 96
# Fanfic-FR 	 52
# Fr. Daoud Lamei 	 22
# Poop FR 	 6
# PLMGSS FR 	 0
# List iptv FR 	 1
# Cardio-FR 	 67
# Naruto & Boruto FR 	 7
# Frim: get new friends on local chat rooms 	 88486
# Fr Agnel Ambarnath 	 117
# Manga-FR - Anime Vostfr 	 291
# Bulgarian French Dictionary Fr 	 603
# News Minecraft.fr 	 881
# payermonstationnement.fr 	 38
# FR Tides 	 1195
# Chemin (fr) 	 44
# FR Calculator 	 7
# FR Forms 	 0
# Sya9a Maroc - FR 	 38
# Fr. Mike Schmitz Audio Teachings 	 4
# Parkinson Exercices FR 	 3
# The SCP Foundation DB fr nn5n 	 114
# iHoroscope - 2018 Daily Horoscope & Astrology 	 398307

# %% [markdown]
# #### STEP 3: Conform the unique count to be the difference of total data set count & duplicate rows

# %%
print('Total count of google data set:', len(google_datarows))
print('Total count of duplicate app rows:', len(duplicate_apps))
print('Difference of the above two:', (len(google_datarows) - len(duplicate_apps)))
print('\n')
print('Unique Dict rows:', len(uniqueapps_maxreview_dict))
# Out:
# Total count of google data set: 10840
# Total count of duplicate app rows: 1181
# Difference of the above two: 9659
#
#
# Unique Dict rows: 9659

# %% [markdown]
# #### STEP4: Create a separate data set which is cleaned of any duplicate rows, and has unique app names with highest review counts

# %%
clean_google_datalist = []
checkappname_samereviewcount_list = []

for approw in google_datarows:
    appname = approw[0]
    reviewval = approw[3]
    
    if uniqueapps_maxreview_dict[appname] == reviewval:
        if appname not in checkappname_samereviewcount_list:
            clean_google_datalist.append(approw)
            checkappname_samereviewcount_list.append(appname)
            
            
explore_data(clean_google_datalist, 0, 5, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# Number of rows: 9659
# Number of columns: 13

# %% [markdown]
# The unique dictionary row count and the newly cleaned data set rows are both equal to 9661

# %% [markdown]
# Removing non-english names
# --------------------------

# %% [markdown]
# Recognizing the app names having non-english characters, by using the corresponding ASCII numbers associated with it.

# %%
def is_english(a_string):
    for ch in a_string:
        if( ord(ch) > 127):
            return False
    return True
    
    
print(is_english('dfdsf爱abchk'))
print(is_english('Instagram'))  
print(is_english('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(is_english('Docs To Go™ Free Office Suite'))  
print(is_english('Instachat 😜'))
# Out:
# False
# True
# False
# False
# False

# %% [markdown]
# Improving the function to allow upto 3 non-ASCII characters

# %%
def is_english(a_string):
    non_asci_count = 0
    
    for ch in a_string:
        if ( ord(ch) > 127):
            non_asci_count += 1
            
    if non_asci_count > 3:
        return False
    else:
        return True
    
print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
# Out:
# True
# True

# %% [markdown]
# Applying the above function to filter both the datasets for non-english apps

# %%
google_eng = []
apple_eng = []

for row in clean_google_datalist:
    name = row[0]
    if is_english(name):
        google_eng.append(row)
        
for row in apple_datarows:
    name = row[1]
    if is_english(name):
        apple_eng.append(row)
        
explore_data(google_eng, 0, 3, True)
print('\n')
explore_data(apple_eng, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 6183
# Number of columns: 16

# %% [markdown]
# Isolating Free Apps
# -------------------

# %%
google_result = []
apple_result = []
non_zero = []

for row in google_eng:
    price = row[7]
    if price == '0':        
        google_result.append(row)            
        
        
for row in apple_eng:
    price = row[4]
    if price == '0.0':
        apple_result.append(row)

print(len(google_result))
print(len(apple_result))
# Out:
# 8862
# 3222

# %% [markdown]
# Andriod Apps - 8862
#
# iOS Apps - 3222

# %% [markdown]
# Grouping Apps by Genre
# -----------------------

# %% [markdown]
# As we mentioned in the introduction, our aim is to determine the kinds of apps that are likely to attract more users because our revenue is highly influenced by the number of people using our apps.
#
# To minimize risks and overhead, our validation strategy for an app idea is comprised of three steps:
#
# Build a minimal Android version of the app, and add it to Google Play.
# If the app has a good response from users, we then develop it further.
# If the app is profitable after six months, we also build an iOS version of the app and add it to the App Store.
# Because our end goal is to add the app on both the App Store and Google Play, we need to find app profiles that are successful on both markets. For instance, a profile that might work well for both markets might be a productivity app that makes use of gamification.
#
# Let's begin the analysis by getting a sense of the most common genres for each market. For this, we'll build a frequency table for the <span style="color: red;">prime_genre</span> column of the App Store data set, and the <span style="color: red;">Genres and Category</span> columns of the Google Play data set.

# %% [markdown]
# #### STEP 1: Function to generate frequency tables showing percentages

# %%
def freq_table(dataset, index):
    freq_t = {}
    freq_t_percent = {}
    
    for row in dataset:
        row_value = row[index]
        if row_value in freq_t:
            freq_t[row_value] += 1
        else:
            freq_t[row_value] = 1
    
    #print(freq_t)     
    #print('\n')
    
    for k in freq_t:
        percent = (freq_t[k] / (len(dataset)) * 100)
        freq_t_percent[k] = percent
    
    return freq_t_percent
    #print(freq_t_percent)       
    
#freq_table(apple_result, -5)

# %% [markdown]
# #### STEP 2: Function to display the percentages in a descending order

# %%
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)
        
    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %% [markdown]
# #### STEP 3. Examine the frequency tables for the "prime_genre" column of the Apple store data set

# %%
display_table(apple_result, -5)
# Out:
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %% [markdown]
# It's evident from the data above, that among the free english apps, more than half 58.16% are Games. Entertainment apps are close to 8%, followed by photo and video apps, which are close to 5%. Only 3.66% of the apps are designed for education, followed by social networking apps which amount for 3.29% of the apps in our data set.
#
# The general impression is that App Store (at least the part containing free English apps) is dominated by apps that are designed for fun (games, entertainment, photo and video, social networking, sports, music, etc.), while apps with practical purposes (education, shopping, utilities, productivity, lifestyle, etc.) are more rare. However, the fact that fun apps are the most numerous doesn't also imply that they also have the greatest number of users — the demand might not be the same as the offer.

# %% [markdown]
# #### STEP 4. Examine the frequency tables for the "Genres" and "Category" columns of the google play data set

# %%
# For Category Column
display_table(google_result, 1)
# Out:
# FAMILY : 18.934777702550214
# GAME : 9.693071541412774
# TOOLS : 8.451816745655607
# BUSINESS : 4.5926427443015125
# LIFESTYLE : 3.9043105393816293
# PRODUCTIVITY : 3.8930264048747465
# FINANCE : 3.7011961182577298
# MEDICAL : 3.5206499661475967
# SPORTS : 3.39652448657188
# PERSONALIZATION : 3.3175355450236967
# COMMUNICATION : 3.238546603475513
# HEALTH_AND_FITNESS : 3.080568720379147
# PHOTOGRAPHY : 2.945159106296547
# NEWS_AND_MAGAZINES : 2.798465357707064
# SOCIAL : 2.663055743624464
# TRAVEL_AND_LOCAL : 2.335815842924848
# SHOPPING : 2.2455427668697814
# BOOKS_AND_REFERENCE : 2.143985556307831
# DATING : 1.8618821936357481
# VIDEO_PLAYERS : 1.7941773865944481
# MAPS_AND_NAVIGATION : 1.399232678853532
# FOOD_AND_DRINK : 1.2412547957571656
# EDUCATION : 1.1735499887158656
# ENTERTAINMENT : 0.9591514330850823
# LIBRARIES_AND_DEMO : 0.9365831640713158
# AUTO_AND_VEHICLES : 0.9252990295644324
# HOUSE_AND_HOME : 0.8237418190024826
# WEATHER : 0.8011735499887158
# EVENTS : 0.7109004739336493
# PARENTING : 0.6544798013992327
# ART_AND_DESIGN : 0.6431956668923494
# COMICS : 0.6206273978785828
# BEAUTY : 0.598059128864816

# %% [markdown]
# The landscape seems significantly different on Google Play: there are not that many apps designed for fun, and it seems that a good number of apps are designed for practical purposes (family, tools, business, lifestyle, productivity, etc.). However, if we investigate this further, we can see that the family category (which accounts for almost 19% of the apps) means mostly games for kids.

# %%
# For Genres Column
display_table(google_result, -4)
# Out:
# Tools : 8.440532611148726
# Entertainment : 6.070864364703228
# Education : 5.348679756262695
# Business : 4.5926427443015125
# Productivity : 3.8930264048747465
# Lifestyle : 3.8930264048747465
# Finance : 3.7011961182577298
# Medical : 3.5206499661475967
# Sports : 3.4642292936131795
# Personalization : 3.3175355450236967
# Communication : 3.238546603475513
# Action : 3.1031369893929135
# Health & Fitness : 3.080568720379147
# Photography : 2.945159106296547
# News & Magazines : 2.798465357707064
# Social : 2.663055743624464
# Travel & Local : 2.324531708417964
# Shopping : 2.2455427668697814
# Books & Reference : 2.143985556307831
# Simulation : 2.0424283457458814
# Dating : 1.8618821936357481
# Arcade : 1.8505980591288649
# Video Players & Editors : 1.7716091175806816
# Casual : 1.7490408485669149
# Maps & Navigation : 1.399232678853532
# Food & Drink : 1.2412547957571656
# Puzzle : 1.128413450688332
# Racing : 0.9930038366057323
# Role Playing : 0.9365831640713158
# Libraries & Demo : 0.9365831640713158
# Auto & Vehicles : 0.9252990295644324
# Strategy : 0.9140148950575491
# House & Home : 0.8237418190024826
# Weather : 0.8011735499887158
# Events : 0.7109004739336493
# Adventure : 0.6770480704129994
# Books & Reference;Education : 0.011284134506883321
# Art & Design;Pretend Play : 0.011284134506883321
# Art & Design;Action & Adventure : 0.011284134506883321
# Arcade;Pretend Play : 0.011284134506883321
# Adventure;Education : 0.011284134506883321

# %% [markdown]
# The difference between the Genres and the Category columns is not crystal clear, but one thing we can notice is that the Genres column is much more granular (it has more categories). We're only looking for the bigger picture at the moment, so we'll only work with the Category column moving forward.
#
# Up to this point, we found that the App Store is dominated by apps designed for fun, while Google Play shows a more balanced landscape of both practical and for-fun apps. Now we'd like to get an idea about the kind of apps that have most users.

# %% [markdown]
# Most Popular Apps by Genre on Google Play
# -------------------------------------------

# %% [markdown]
# One way to find out what genres are the most popular (have the most users) is to calculate the average number of installs for each app genre. For the Google Play data set, we can find this information in the Installs column, but for the App Store data set this information is missing. As a workaround, we'll take the total number of user ratings as a proxy, which we can find in the rating_count_tot app.
#
# Below, we calculate the average number of user ratings per app genre on the App Store:

# %%
apple_genres = freq_table(apple_result, -5)

for g in apple_genres:
    # total user ratings of a specific genre
    uratings_total = 0
    
    # total of all rows belonging to generes listed in apple_result
    genre_total = 0   
    
    for row in apple_result:
        row_genre = row[-5]
        if row_genre == g:
            u_ratings = float(row[5])
            uratings_total += u_ratings
            genre_total += 1
            
    avg_ratings = uratings_total / genre_total
    print(g, ':', avg_ratings)
# Out:
# Social Networking : 71548.34905660378
# Photo & Video : 28441.54375
# Games : 22788.6696905016
# Music : 57326.530303030304
# Reference : 74942.11111111111
# Health & Fitness : 23298.015384615384
# Weather : 52279.892857142855
# Utilities : 18684.456790123455
# Travel : 28243.8
# Shopping : 26919.690476190477
# News : 21248.023255813954
# Navigation : 86090.33333333333
# Lifestyle : 16485.764705882353
# Entertainment : 14029.830708661417
# Food & Drink : 33333.92307692308
# Sports : 23008.898550724636
# Book : 39758.5
# Finance : 31467.944444444445
# Education : 7003.983050847458
# Productivity : 21028.410714285714
# Business : 7491.117647058823
# Catalogs : 4004.0
# Medical : 612.0

# %% [markdown]
# On average, navigation apps have the highest number of user reviews.

# %%
for row in apple_result:
    if row[-5] == 'Navigation':
        # print AppName : NoOfRatings
        print(row[1], ':', row[5])
# Out:
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Google Maps - Navigation & Transit : 154911
# Geocaching® : 12811
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5

# %% [markdown]
# The same pattern applies to social networking apps, where the average number is heavily influenced by a few giants like Facebook, Pinterest, Skype, etc. Same applies to music apps, where a few big players like Pandora, Spotify, and Shazam heavily influence the average number.

# %%
for row in apple_result:
    if row[-5] == 'Reference':
        # print AppName : NoOfRatings
        print(row[1], ':', row[5])
# Out:
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Google Translate : 26786
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# Merriam-Webster Dictionary : 16849
# Night Sky : 12122
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# WWDC : 762
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# VPN Express : 14
# Real Bike Traffic Rider Virtual Reality Glasses : 8
# 教えて!goo : 0
# Jishokun-Japanese English Dictionary & Translator : 0

# %% [markdown]
# Reference apps have 74,942 user ratings on average, but it's actually the Bible and Dictionary.com which skew up the average rating.
#
# the fact that the App Store is dominated by for-fun apps. This suggests the market might be a bit saturated with for-fun apps, which means a practical app might have more of a chance to stand out among the huge number of apps on the App Store.

# %% [markdown]
# Most Popular Apps by Genre on Google Play
# ----------------------------------------------------------------

# %% [markdown]
# For the Google Play market, we actually have data about the number of installs, so we should be able to get a clearer picture about genre popularity. However, the install numbers don't seem precise enough — we can see that most values are open-ended (100+, 1,000+, 5,000+, etc.):

# %%
# For Install Column
display_table(google_result, 5)
# Out:
# 1,000,000+ : 15.741367637102236
# 100,000+ : 11.554953735048521
# 10,000,000+ : 10.516813360415256
# 10,000+ : 10.200857594222523
# 1,000+ : 8.395396073121193
# 100+ : 6.917174452719477
# 5,000,000+ : 6.838185511171294
# 500,000+ : 5.574362446400361
# 50,000+ : 4.773188896411646
# 5,000+ : 4.513653802753328
# 10+ : 3.5432182351613632
# 500+ : 3.2498307379823967
# 50,000,000+ : 2.2906793048973144
# 100,000,000+ : 2.1214172872940646
# 50+ : 1.9183028661701647
# 5+ : 0.7898894154818324
# 1+ : 0.5077860528097494
# 500,000,000+ : 0.2708192281651997
# 1,000,000,000+ : 0.22568269013766643
# 0+ : 0.045136538027533285
# 0 : 0.011284134506883321

# %% [markdown]
# One problem with this data is that is not precise. For instance, we don't know whether an app with 100,000+ installs has 100,000 installs, 200,000, or 350,000. However, we don't need very precise data for our purposes — we only want to get an idea which app genres attract the most users, and we don't need perfect precision with respect to the number of users.
#
# We're going to leave the numbers as they are, which means that we'll consider that an app with 100,000+ installs has 100,000 installs, and an app with 1,000,000+ installs has 1,000,000 installs, and so on.
#
# To perform computations, however, we'll need to convert each install number to float — this means that we need to remove the commas and the plus characters, otherwise the conversion will fail and raise an error. We'll do this directly in the loop below, where we also compute the average number of installs for each genre (category).

# %%
google_category = freq_table(google_result, 1)

for c in google_category:
    total_uinstall = 0
    category_total = 0
    for row in google_result:
        row_category = row[1]
        if row_category == c:
            u_install = row[5]
            u_install = u_install.replace(',','')
            u_install = u_install.replace('+', '')
            total_uinstall += float(u_install)
            category_total += 1
    avg_u_install = total_uinstall / category_total
    print(c, ':', avg_u_install)
# Out:
# ART_AND_DESIGN : 1986335.0877192982
# AUTO_AND_VEHICLES : 647317.8170731707
# BEAUTY : 513151.88679245283
# BOOKS_AND_REFERENCE : 8767811.894736841
# BUSINESS : 1712290.1474201474
# COMICS : 817657.2727272727
# COMMUNICATION : 38456119.167247385
# DATING : 854028.8303030303
# EDUCATION : 1820673.076923077
# ENTERTAINMENT : 11640705.88235294
# EVENTS : 253542.22222222222
# FINANCE : 1387692.475609756
# FOOD_AND_DRINK : 1924897.7363636363
# HEALTH_AND_FITNESS : 4188821.9853479853
# HOUSE_AND_HOME : 1331540.5616438356
# LIBRARIES_AND_DEMO : 638503.734939759
# LIFESTYLE : 1437816.2687861272
# GAME : 15560965.599534342
# FAMILY : 3694276.334922527
# MEDICAL : 120616.48717948717
# SOCIAL : 23253652.127118643
# SHOPPING : 7036877.311557789
# PHOTOGRAPHY : 17805627.643678162
# SPORTS : 3638640.1428571427
# TRAVEL_AND_LOCAL : 13984077.710144928
# TOOLS : 10682301.033377837
# PERSONALIZATION : 5201482.6122448975
# PRODUCTIVITY : 16787331.344927534
# PARENTING : 542603.6206896552
# WEATHER : 5074486.197183099
# VIDEO_PLAYERS : 24727872.452830188
# NEWS_AND_MAGAZINES : 9549178.467741935
# MAPS_AND_NAVIGATION : 4056941.7741935486

# %% [markdown]
# On average, communication apps have the most installs: 38,456,119. This number is heavily skewed up by a few apps that have over one billion installs (WhatsApp, Facebook Messenger, Skype, Google Chrome, Gmail, and Hangouts), and a few others with over 100 and 500 million installs

# %%
for app in google_result:
    if app[1] == 'COMMUNICATION' and (app[5] == '1,000,000,000+'
                                      or app[5] == '500,000,000+'
                                      or app[5] == '100,000,000+'):
        print(app[0], ':', app[5])
# Out:
# WhatsApp Messenger : 1,000,000,000+
# imo beta free calls and text : 100,000,000+
# Android Messages : 100,000,000+
# Google Duo - High Quality Video Calls : 500,000,000+
# Messenger – Text and Video Chat for Free : 1,000,000,000+
# imo free video calls and chat : 500,000,000+
# Skype - free IM & video calls : 1,000,000,000+
# Who : 100,000,000+
# GO SMS Pro - Messenger, Free Themes, Emoji : 100,000,000+
# LINE: Free Calls & Messages : 500,000,000+
# Google Chrome: Fast & Secure : 1,000,000,000+
# Firefox Browser fast & private : 100,000,000+
# UC Browser - Fast Download Private & Secure : 500,000,000+
# Gmail : 1,000,000,000+
# Hangouts : 1,000,000,000+
# Messenger Lite: Free Calls & Messages : 100,000,000+
# Kik : 100,000,000+
# KakaoTalk: Free Calls & Text : 100,000,000+
# Opera Mini - fast web browser : 100,000,000+
# Opera Browser: Fast and Secure : 100,000,000+
# Telegram : 100,000,000+
# Truecaller: Caller ID, SMS spam blocking & Dialer : 100,000,000+
# UC Browser Mini -Tiny Fast Private & Secure : 100,000,000+
# Viber Messenger : 500,000,000+
# WeChat : 100,000,000+
# Yahoo Mail – Stay Organized : 100,000,000+
# BBM - Free Calls & Messages : 100,000,000+

# %%
under_100_m = []

for app in google_result:
    n_installs = app[5]
    n_installs = n_installs.replace(',', '')
    n_installs = n_installs.replace('+', '')
    if (app[1] == 'COMMUNICATION') and (float(n_installs) < 100000000):
        under_100_m.append(float(n_installs))
        
sum(under_100_m) / len(under_100_m)
# Out:
# 3603485.3884615386

# %% [markdown]
# Again, the main concern is that these app genres might seem more popular than they really are. Moreover, these niches seem to be dominated by a few giants who are hard to compete against.
#
# The game genre seems pretty popular, but previously we found out this part of the market seems a bit saturated, so we'd like to come up with a different app recommendation if possible.
#
# The books and reference genre looks fairly popular as well, with an average number of installs of 8,767,811. It's interesting to explore this in more depth, since we found this genre has some potential to work well on the App Store, and our aim is to recommend an app genre that shows potential for being profitable on both the App Store and Google Play.
#
# Let's take a look at some of the apps from this genre and their number of installs:

# %%
for app in google_result:
    if app[1] == 'BOOKS_AND_REFERENCE':
        print(app[0], ':', app[5])
# Out:
# E-Book Read - Read Book for free : 50,000+
# Download free book with green book : 100,000+
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Free Panda Radio Music : 100,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# English Grammar Complete Handbook : 500,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# Google Play Books : 1,000,000,000+
# AlReader -any text book reader : 5,000,000+
# Offline English Dictionary : 100,000+
# Offline: English to Tagalog Dictionary : 500,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# Recipes of Prophetic Medicine for free : 500,000+
# ReadEra – free ebook reader : 1,000,000+
# Anonymous caller detection : 10,000+
# Ebook Reader : 5,000,000+
# Litnet - E-books : 100,000+
# Read books online : 5,000,000+
# English to Urdu Dictionary : 500,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# English Persian Dictionary : 500,000+
# Flybook : 500,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# English translation from Bengali : 100,000+
# Pdf Book Download - Read Pdf Book : 100,000+
# Free Book Reader : 100,000+
# eBoox new: Reader for fb2 epub zip books : 50,000+
# Only 30 days in English, the guideline is guaranteed : 500,000+
# Moon+ Reader : 10,000,000+
# SH-02J Owner's Manual (Android 8.0) : 50,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Azpen eReader : 500,000+
# URBANO V 02 instruction manual : 100,000+
# Bible : 100,000,000+
# C Programs and Reference : 50,000+
# C Offline Tutorial : 1,000+
# C Programs Handbook : 50,000+
# Amazon Kindle : 100,000,000+
# Aab e Hayat Full Novel : 100,000+
# Aldiko Book Reader : 10,000,000+
# Google I/O 2018 : 500,000+
# R Language Reference Guide : 10,000+
# Learn R Programming Full : 5,000+
# R Programing Offline Tutorial : 1,000+
# Guide for R Programming : 5+
# Learn R Programming : 10+
# R Quick Reference Big Data : 1,000+
# V Made : 100,000+
# Wattpad 📖 Free Books : 100,000,000+
# Dictionary - WordWeb : 5,000,000+
# Guide (for X-MEN) : 100,000+
# AC Air condition Troubleshoot,Repair,Maintenance : 5,000+
# AE Bulletins : 1,000+
# Ae Allah na Dai (Rasa) : 10,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Ag PhD Field Guide : 10,000+
# Ag PhD Deficiencies : 10,000+
# Ag PhD Planting Population Calculator : 1,000+
# Ag PhD Soybean Diseases : 1,000+
# Fertilizer Removal By Crop : 50,000+
# A-J Media Vault : 50+
# Al-Quran (Free) : 10,000,000+
# Al Quran (Tafsir & by Word) : 500,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al-Muhaffiz : 50,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Al-Quran 30 Juz free copies : 500,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Surah Al-Waqiah : 100,000+
# Hisnul Al Muslim - Hisn Invocations & Adhkaar : 100,000+
# Satellite AR : 1,000,000+
# Audiobooks from Audible : 100,000,000+
# Kinot & Eichah for Tisha B'Av : 10,000+
# AW Tozer Devotionals - Daily : 5,000+
# Tozer Devotional -Series 1 : 1,000+
# The Pursuit of God : 1,000+
# AY Sing : 5,000+
# Ay Hasnain k Nana Milad Naat : 10,000+
# Ay Mohabbat Teri Khatir Novel : 10,000+
# Arizona Statutes, ARS (AZ Law) : 1,000+
# Oxford A-Z of English Usage : 1,000,000+
# BD Fishpedia : 1,000+
# BD All Sim Offer : 10,000+
# Youboox - Livres, BD et magazines : 500,000+
# B&H Kids AR : 10,000+
# B y H Niños ES : 5,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# Borneo Bible, BM Bible : 10,000+
# MOD Black for BM : 100+
# BM Box : 1,000+
# Anime Mod for BM : 100+
# NOOK: Read eBooks & Magazines : 10,000,000+
# NOOK Audiobooks : 500,000+
# NOOK App for NOOK Devices : 500,000+
# Browsery by Barnes & Noble : 5,000+
# bp e-store : 1,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# BR Ambedkar Biography & Quotes : 10,000+
# BU Alsace : 100+
# Catholic La Bu Zo Kam : 500+
# Khrifa Hla Bu (Solfa) : 10+
# Kristian Hla Bu : 10,000+
# SA HLA BU : 1,000+
# Learn SAP BW : 500+
# Learn SAP BW on HANA : 500+
# CA Laws 2018 (California Laws and Codes) : 5,000+
# Bootable Methods(USB-CD-DVD) : 10,000+
# cloudLibrary : 100,000+
# SDA Collegiate Quarterly : 500+
# Sabbath School : 100,000+
# Cypress College Library : 100+
# Stats Royale for Clash Royale : 1,000,000+
# GATE 21 years CS Papers(2011-2018 Solved) : 50+
# Learn CT Scan Of Head : 5,000+
# Easy Cv maker 2018 : 10,000+
# How to Write CV : 100,000+
# CW Nuclear : 1,000+
# CY Spray nozzle : 10+
# BibleRead En Cy Zh Yue : 5+
# CZ-Help : 5+
# Modlitební knížka CZ : 500+
# Guide for DB Xenoverse : 10,000+
# Guide for DB Xenoverse 2 : 10,000+
# Guide for IMS DB : 10+
# DC HSEMA : 5,000+
# DC Public Library : 1,000+
# Painting Lulu DC Super Friends : 1,000+
# Dictionary : 10,000,000+
# Fix Error Google Playstore : 1,000+
# D. H. Lawrence Poems FREE : 1,000+
# Bilingual Dictionary Audio App : 5,000+
# DM Screen : 10,000+
# wikiHow: how to do anything : 1,000,000+
# Dr. Doug's Tips : 1,000+
# Bible du Semeur-BDS (French) : 50,000+
# La citadelle du musulman : 50,000+
# DV 2019 Entry Guide : 10,000+
# DV 2019 - EDV Photo & Form : 50,000+
# DV 2018 Winners Guide : 1,000+
# EB Annual Meetings : 1,000+
# EC - AP & Telangana : 5,000+
# TN Patta Citta & EC : 10,000+
# AP Stamps and Registration : 10,000+
# CompactiMa EC pH Calibration : 100+
# EGW Writings 2 : 100,000+
# EGW Writings : 1,000,000+
# Bible with EGW Comments : 100,000+
# My Little Pony AR Guide : 1,000,000+
# SDA Sabbath School Quarterly : 500,000+
# Duaa Ek Ibaadat : 5,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+
# EP Research Service : 1,000+
# Hymnes et Louanges : 100,000+
# EU Charter : 1,000+
# EU Data Protection : 1,000+
# EU IP Codes : 100+
# EW PDF : 5+
# BakaReader EX : 100,000+
# EZ Quran : 50,000+
# FA Part 1 & 2 Past Papers Solved Free – Offline : 5,000+
# La Fe de Jesus : 1,000+
# La Fe de Jesús : 500+
# Le Fe de Jesus : 500+
# Florida - Pocket Brainbook : 1,000+
# Florida Statutes (FL Code) : 1,000+
# English To Shona Dictionary : 10,000+
# Greek Bible FP (Audio) : 1,000+
# Golden Dictionary (FR-AR) : 500,000+
# Fanfic-FR : 5,000+
# Bulgarian French Dictionary Fr : 10,000+
# Chemin (fr) : 1,000+
# The SCP Foundation DB fr nn5n : 1,000+

# %% [markdown]
# The book and reference genre includes a variety of apps: software for processing and reading ebooks, various collections of libraries, dictionaries, tutorials on programming or languages, etc. It seems there's still a small number of extremely popular apps that skew the average.

# %%
for app in google_result:
    if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000,000+'
                                            or app[5] == '500,000,000+'
                                            or app[5] == '100,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Google Play Books : 1,000,000,000+
# Bible : 100,000,000+
# Amazon Kindle : 100,000,000+
# Wattpad 📖 Free Books : 100,000,000+
# Audiobooks from Audible : 100,000,000+

# %% [markdown]
# However, it looks like there are only a few very popular apps, so this market still shows potential. Let's try to get some app ideas based on the kind of apps that are somewhere in the middle in terms of popularity (between 1,000,000 and 100,000,000 downloads)

# %%
for app in google_result:
    if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000+'
                                            or app[5] == '5,000,000+'
                                            or app[5] == '10,000,000+'
                                            or app[5] == '50,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# AlReader -any text book reader : 5,000,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# ReadEra – free ebook reader : 1,000,000+
# Ebook Reader : 5,000,000+
# Read books online : 5,000,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# Moon+ Reader : 10,000,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Aldiko Book Reader : 10,000,000+
# Dictionary - WordWeb : 5,000,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Al-Quran (Free) : 10,000,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Satellite AR : 1,000,000+
# Oxford A-Z of English Usage : 1,000,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# NOOK: Read eBooks & Magazines : 10,000,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# Stats Royale for Clash Royale : 1,000,000+
# Dictionary : 10,000,000+
# wikiHow: how to do anything : 1,000,000+
# EGW Writings : 1,000,000+
# My Little Pony AR Guide : 1,000,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+

# %% [markdown]
# This niche seems to be dominated by software for processing and reading ebooks, as well as various collections of libraries and dictionaries, so it's probably not a good idea to build similar apps since there'll be some significant competition.
#
# We also notice there are quite a few apps built around the book Quran, which suggests that building an app around a popular book can be profitable. It seems that taking a popular book (perhaps a more recent book) and turning it into an app could be profitable for both the Google Play and the App Store markets.
#
# However, it looks like the market is already full of libraries, so we need to add some special features besides the raw version of the book. This might include daily quotes from the book, an audio version of the book, quizzes on the book, a forum where people can discuss the book, etc.

# %% [markdown]
# Conclusions
# ------------

# %% [markdown]
# In this project, we analyzed data about the App Store and Google Play mobile apps with the goal of recommending an app profile that can be profitable for both markets.
#
# We concluded that taking a popular book (perhaps a more recent book) and turning it into an app could be profitable for both the Google Play and the App Store markets. The markets are already full of libraries, so we need to add some special features besides the raw version of the book. This might include daily quotes from the book, an audio version of the book, quizzes on the book, a forum where people can discuss the book, etc.
